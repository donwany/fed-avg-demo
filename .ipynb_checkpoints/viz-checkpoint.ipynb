# %%
import pandas as pd
import seaborn as sns

# %%
df_iid10e1 = pd.read_csv('sim_data/b10e1.csv')
df_iid10e5 = pd.read_csv('sim_data/b10e5.csv')
df_iid10e20 = pd.read_csv('sim_data/b10e20.csv')

df_iid50e1 = pd.read_csv('sim_data/b50e1.csv')
df_iid50e5 = pd.read_csv('sim_data/b50e5.csv')
df_iid50e20 = pd.read_csv('sim_data/b50e20.csv')

df_iid600e1 = pd.read_csv('sim_data/b600e1.csv')
df_iid600e5 = pd.read_csv('sim_data/b600e5.csv')
df_iid600e20 = pd.read_csv('sim_data/b600e20.csv')

# %%
df_iid1.head()
# Out:
#    Step  non_iid - test/acc  non_iid - test/acc__MIN  non_iid - test/acc__MAX
# 0     0              0.1619                   0.1619                   0.1619
# 1     1              0.2143                   0.2143                   0.2143
# 2     2              0.0942                   0.0942                   0.0942
# 3     3              0.3096                   0.3096                   0.3096
# 4     4              0.4662                   0.4662                   0.4662

# %%
df_iid1['non_iid - test/acc'].min(), df_iid1['non_iid - test/acc__MAX'].max()
# Out:
# (0.0942, 0.99)

# %%
plt.figure(figsize=(4,4), tight_layout=True)

p1 = df_iid1['non_iid - test/acc__MAX']
p2 = df_iid5['non_iid - test/acc__MAX']
p3 = df_iid20['non_iid - test/acc__MAX']

p4 = df_iid50e1['non_iid - test/acc__MAX']
p5 = df_iid10e20['non_iid - test/acc__MAX']
p6 = df_iid10e5['non_iid - test/acc__MAX']

#p7 = df_iid10e20['non_iid - test/acc__MAX']
#p8 = df_iid10e20['non_iid - test/acc__MAX']
#p9 = df_iid10e20['non_iid - test/acc__MAX']

plt.plot(p1, marker='',color='blue', linewidth=1, linestyle='solid')
plt.plot(p2, marker='', color='blue', linewidth=1, linestyle='dashed')
plt.plot(p3, marker='', color='blue', linewidth=1, linestyle='dotted')

plt.plot(p4, marker='', color='orange', linewidth=1, linestyle='solid')
plt.plot(p5, marker='', color='orange', linewidth=1, linestyle='dashed')
plt.plot(p6, marker='', color='orange', linewidth=1, linestyle='dotted')

#plt.plot(p7, marker='', color='red', linewidth=1, linestyle='solid')
#plt.plot(p8, marker='', color='red', linewidth=1, linestyle='dashed')
#plt.plot(p9, marker='', color='red', linewidth=1, linestyle='dotted')

plt.xlabel('Communication Rounds')
plt.ylabel('Test Accuracy')
plt.legend(title='', title_fontsize = 13, labels=["B=600, E=1", "B=600, E=5","B=600, E=20","B=10, E=5","B=10, E=20","B=50, E=1"])
plt.title("MNIST CNN IID")
#plt.xticks(fontsize=12)
#plt.yticks(fontsize=12)
plt.show()
